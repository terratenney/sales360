# %%
import pandas as pd
from matplotlib import pyplot
import seaborn
import pandas as pd
import sys, getopt
import json
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans,MiniBatchKMeans
from math import sqrt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
import json
from sklearn.linear_model import LogisticRegression
from sklearn import cross_validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import scale
import pdb
import cPickle as cp
import pickle

# %%
df = pd.read_csv("../data/train.csv")
#df_test = pd.read_csv("../data/test_v2.csv")

# %%
df.shape
# Out:
# (665249, 25)

# %%
df.risk_factor.value_counts()
# Out:
# 3    117571
# 4    110754
# 1     99476
# 2     97030
# dtype: int64

# %%
df.describe()
# Out:
#            customer_ID    shopping_pt    record_type            day  \
# count    665249.000000  665249.000000  665249.000000  665249.000000
# mean   10076553.440219       4.219966       0.145824       1.969429
# std       44049.778757       2.394369       0.352930       1.453470
# min    10000000.000000       1.000000       0.000000       0.000000
# 25%    10038523.000000       2.000000       0.000000       1.000000
# 50%    10076403.000000       4.000000       0.000000       2.000000
# 75%    10114696.000000       6.000000       0.000000       3.000000
# max    10152724.000000      13.000000       1.000000       6.000000
#
#             location     group_size      homeowner        car_age  \
# count  665249.000000  665249.000000  665249.000000  665249.000000
# mean    12271.543022       1.234784       0.536229       8.139437
# std      1564.789415       0.461036       0.498686       5.764598
# min     10001.000000       1.000000       0.000000       0.000000
# 25%     10936.000000       1.000000       0.000000       3.000000
# 50%     12027.000000       1.000000       1.000000       7.000000
# 75%     13426.000000       1.000000       1.000000      12.000000
# max     16580.000000       4.000000       1.000000      85.000000
#
#          risk_factor     age_oldest      ...           C_previous  \
# count  424831.000000  665249.000000      ...        646538.000000
# mean        2.563996      44.992403      ...             2.444718
# std         1.111584      17.403440      ...             1.034596
# min         1.000000      18.000000      ...             1.000000
# 25%         2.000000      28.000000      ...             1.000000
# 50%         3.000000      44.000000      ...             3.000000
# 75%         4.000000      60.000000      ...             3.000000
# max         4.000000      75.000000      ...             4.000000
#
#        duration_previous              A              B              C  \
# count      646538.000000  665249.000000  665249.000000  665249.000000
# mean            6.003774       0.927546       0.454236       2.275265
# std             4.680793       0.595221       0.497902       0.990798
# min             0.000000       0.000000       0.000000       1.000000
# 25%             2.000000       1.000000       0.000000       1.000000
# 50%             5.000000       1.000000       0.000000       2.000000
# 75%             9.000000       1.000000       1.000000       3.000000
# max            15.000000       2.000000       1.000000       4.000000
#
#                    D              E              F              G  \
# count  665249.000000  665249.000000  665249.000000  665249.000000
# mean        2.454299       0.445193       1.162768       2.275120
# std         0.753953       0.496987       0.943594       0.909567
# min         1.000000       0.000000       0.000000       1.000000
# 25%         2.000000       0.000000       0.000000       2.000000
# 50%         3.000000       0.000000       1.000000       2.000000
# 75%         3.000000       1.000000       2.000000       3.000000
# max         3.000000       1.000000       3.000000       4.000000
#
#                 cost
# count  665249.000000
# mean      635.785008
# std        45.993758
# min       260.000000
# 25%       605.000000
# 50%       635.000000
# 75%       665.000000
# max       922.000000
#
# [8 rows x 22 columns]

# %%
df.state.value_counts()
len(df.customer_ID.value_counts())
# Out:
# 97009

# %%
df.columns
# Out:
# Index([u'customer_ID', u'shopping_pt', u'record_type', u'day', u'time', u'state', u'location', u'group_size', u'homeowner', u'car_age', u'car_value', u'risk_factor', u'age_oldest', u'age_youngest', u'married_couple', u'C_previous', u'duration_previous', u'A', u'B', u'C', u'D', u'E', u'F', u'G', u'cost'], dtype='object')

# %%
df.married_couple.value_counts()
# Out:
# 0    525692
# 1    139557
# dtype: int64

# %%
print df.homeowner.value_counts()
print df.car_age.value_counts()
print df.car_value.value_counts()
print df.A.value_counts()
# Out:
# 1    356726
# 0    308523
# dtype: int64
# 1     71650
# 2     50389
# 7     46752
# 8     44453
# 6     44363
# 9     44218
# 4     40991
# 3     40391
# 10    39301
# 11    36173
# 5     32806
# 12    32113
# 13    26628
# 14    25026
# 15    19041
# ...
# 62    15
# 61    14
# 51    14
# 53    13
# 52    11
# 59    10
# 58     8
# 57     7
# 64     6
# 75     6
# 55     6
# 65     5
# 60     4
# 85     4
# 54     1
# Length: 67, dtype: int64
# e    219251
# f    177204
# d    113174
# g     98152
# h     28976
# c     20820
# i      3603
# b      1402
# a      1136
# dtype: int64
# 1    426067
# 0    143691
# 2     95491
# dtype: int64

# %%
df.C_previous.value_counts()
# Out:
# 3    271160
# 1    172007
# 2    109184
# 4     94187
# dtype: int64

# %%
print df.age_youngest.value_counts()
# Out:
# 75    34262
# 23    24208
# 24    23635
# 25    23509
# 22    22290
# 26    20510
# 27    17718
# 21    17311
# 28    16832
# 29    14437
# 30    13807
# 20    13480
# 31    12961
# 32    12520
# 33    12118
# 34    11466
# 35    11080
# 55    10298
# 42    10200
# 19    10182
# 43    10117
# 52    10026
# 36     9904
# 48     9829
# 37     9825
# 53     9803
# 46     9743
# 51     9713
# 49     9674
# 58     9673
# 56     9581
# 38     9568
# 41     9533
# 54     9511
# 50     9510
# 45     9380
# 40     9365
# 44     9291
# 65     9142
# 57     9120
# 39     9085
# 47     8931
# 59     8901
# 60     8859
# 66     8800
# 62     8707
# 61     8697
# 63     8606
# 64     8591
# 70     7295
# 69     6987
# 68     6397
# 67     6187
# 71     6102
# 72     5234
# 73     5152
# 18     5093
# 74     5048
# 16     4478
# 17     2967
# Length: 60, dtype: int64

# %%
print df.age_oldest.value_counts()
# Out:
# 75    45211
# 24    21627
# 23    21489
# 25    21278
# 22    19692
# 26    18679
# 27    16046
# 28    15180
# 21    14255
# 29    13179
# 30    12874
# 31    11982
# 32    11658
# 33    11461
# 43    11321
# 55    11206
# 42    11129
# 52    11029
# 34    10980
# 53    10839
# 46    10748
# 56    10680
# 35    10665
# 48    10632
# 49    10595
# 54    10558
# 58    10462
# 51    10447
# 50    10250
# 44    10205
# 45    10190
# 20    10180
# 59    10169
# 41    10135
# 36     9948
# 57     9873
# 47     9860
# 37     9831
# 66     9707
# 38     9700
# 63     9663
# 65     9651
# 60     9617
# 40     9573
# 61     9491
# 39     9480
# 62     9348
# 64     9315
# 70     8278
# 69     7604
# 67     7538
# 68     6957
# 71     6825
# 19     6592
# 72     6194
# 73     5861
# 74     5646
# 18     1666
# Length: 58, dtype: int64

# %%
df.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000000            1            0    0  08:35    IN     10001
# 1     10000000            2            0    0  08:38    IN     10001
# 2     10000000            3            0    0  08:38    IN     10001
# 3     10000000            4            0    0  08:39    IN     10001
# 4     10000000            5            0    0  11:55    IN     10001
#
#    group_size  homeowner  car_age   ...    C_previous  duration_previous  A  \
# 0           2          0        2   ...             1                  2  1
# 1           2          0        2   ...             1                  2  1
# 2           2          0        2   ...             1                  2  1
# 3           2          0        2   ...             1                  2  1
# 4           2          0        2   ...             1                  2  1
#
#    B  C  D  E  F  G  cost
# 0  0  2  2  1  2  2   633
# 1  0  2  2  1  2  1   630
# 2  0  2  2  1  2  1   630
# 3  0  2  2  1  2  1   630
# 4  0  2  2  1  2  1   630
#
# [5 rows x 25 columns]

# %%
print df.duration_previous.value_counts()
# Out:
# 1     81570
# 15    79849
# 2     79595
# 3     70800
# 4     57485
# 5     49372
# 6     45379
# 7     37768
# 8     30752
# 9     26244
# 0     24926
# 10    18094
# 11    12718
# 12    11284
# 13    10963
# 14     9739
# dtype: int64

# %%
df.time.value_counts()
# Out:
# 14:35    1553
# 14:59    1489
# 14:57    1471
# 15:22    1454
# 15:20    1453
# 15:09    1452
# 14:40    1441
# 14:16    1440
# 14:39    1435
# 15:13    1432
# 14:38    1430
# 13:42    1428
# 15:03    1425
# 14:25    1423
# 14:56    1420
# ...
# 01:34    1
# 01:30    1
# 01:59    1
# 02:40    1
# 02:04    1
# 02:03    1
# 04:46    1
# 04:00    1
# 04:02    1
# 05:12    1
# 05:11    1
# 05:10    1
# 06:27    1
# 04:47    1
# 05:23    1
# Length: 1204, dtype: int64

# %%
df.head(100)
# Out:
#     customer_ID  shopping_pt  record_type  day   time state  location  \
# 0      10000000            1            0    0  08:35    IN     10001
# 1      10000000            2            0    0  08:38    IN     10001
# 2      10000000            3            0    0  08:38    IN     10001
# 3      10000000            4            0    0  08:39    IN     10001
# 4      10000000            5            0    0  11:55    IN     10001
# 5      10000000            6            0    0  11:57    IN     10001
# 6      10000000            7            0    0  11:58    IN     10001
# 7      10000000            8            0    0  12:03    IN     10001
# 8      10000000            9            1    0  12:07    IN     10001
# 9      10000005            1            0    3  08:56    NY     10006
# 10     10000005            2            0    3  08:56    NY     10006
# 11     10000005            3            0    3  08:57    NY     10006
# 12     10000005            4            0    3  08:58    NY     10006
# 13     10000005            5            0    3  08:58    NY     10006
# 14     10000005            6            1    3  09:09    NY     10006
# 15     10000007            1            0    4  08:35    PA     10008
# 16     10000007            2            0    4  08:36    PA     10008
# 17     10000007            3            0    4  08:36    PA     10008
# 18     10000007            4            0    4  08:38    PA     10008
# 19     10000007            5            0    4  08:39    PA     10008
# 20     10000007            6            0    4  08:41    PA     10008
# 21     10000007            7            0    4  08:43    PA     10008
# 22     10000007            8            1    4  14:26    PA     10008
# 23     10000013            1            0    2  16:31    WV     10014
# 24     10000013            2            0    2  16:32    WV     10014
# 25     10000013            3            0    2  16:36    WV     10014
# 26     10000013            4            1    4  09:31    WV     10014
# 27     10000014            1            0    4  16:30    MO     10015
# 28     10000014            2            0    4  16:31    MO     10015
# 29     10000014            3            0    4  16:32    MO     10015
# ..          ...          ...          ...  ...    ...   ...       ...
# 70     10000027            2            0    0  09:12    IN     10029
# 71     10000027            3            0    0  09:13    IN     10029
# 72     10000027            4            0    0  09:14    IN     10029
# 73     10000027            5            0    0  09:15    IN     10029
# 74     10000027            6            1    2  08:03    IN     10029
# 75     10000028            1            0    5  15:46    FL     10030
# 76     10000028            2            0    5  15:47    FL     10030
# 77     10000028            3            0    5  15:48    FL     10030
# 78     10000028            4            0    5  15:49    FL     10030
# 79     10000028            5            0    5  15:50    FL     10030
# 80     10000028            6            1    6  11:44    FL     10030
# 81     10000031            1            0    4  18:20    OR     10033
# 82     10000031            2            0    4  18:24    OR     10033
# 83     10000031            3            0    4  18:34    OR     10033
# 84     10000031            4            0    4  18:37    OR     10033
# 85     10000031            5            0    4  18:39    OR     10033
# 86     10000031            6            0    4  18:42    OR     10033
# 87     10000031            7            0    4  18:43    OR     10033
# 88     10000031            8            1    4  19:09    OR     10033
# 89     10000032            1            0    0  18:15    OR     10034
# 90     10000032            2            0    0  18:15    OR     10034
# 91     10000032            3            0    0  18:18    OR     10034
# 92     10000032            4            0    0  18:19    OR     10034
# 93     10000032            5            0    0  18:26    OR     10034
# 94     10000032            6            0    0  18:27    OR     10034
# 95     10000032            7            1    1  18:37    OR     10034
# 96     10000033            1            0    0  17:40    WA     10035
# 97     10000033            2            0    0  17:42    WA     10035
# 98     10000033            3            0    0  17:42    WA     10035
# 99     10000033            4            0    0  17:44    WA     10035
#
#     group_size  homeowner  car_age   ...    C_previous  duration_previous  A  \
# 0            2          0        2   ...             1                  2  1
# 1            2          0        2   ...             1                  2  1
# 2            2          0        2   ...             1                  2  1
# 3            2          0        2   ...             1                  2  1
# 4            2          0        2   ...             1                  2  1
# 5            2          0        2   ...             1                  2  1
# 6            2          0        2   ...             1                  2  1
# 7            2          0        2   ...             1                  2  1
# 8            2          0        2   ...             1                  2  1
# 9            1          0       10   ...             3                 13  1
# 10           1          0       10   ...             3                 13  1
# 11           1          0       10   ...             3                 13  1
# 12           1          0       10   ...             3                 13  0
# 13           1          0       10   ...             3                 13  0
# 14           1          0       10   ...             3                 13  0
# 15           1          0       11   ...             2                  4  0
# 16           1          0       11   ...             2                  4  0
# 17           1          0       11   ...             2                  4  0
# 18           1          0       11   ...             2                  4  0
# 19           1          0       11   ...             2                  4  0
# 20           1          0       11   ...             2                  4  0
# 21           1          0       11   ...             2                  4  0
# 22           1          0       11   ...             2                  4  0
# 23           2          1        3   ...             3                  3  1
# 24           2          1        3   ...             3                  3  1
# 25           2          1        3   ...             3                  3  1
# 26           2          1        3   ...             3                  3  1
# 27           1          0        5   ...             1                  2  1
# 28           1          0        5   ...             1                  2  2
# 29           1          0        5   ...             1                  2  1
# ..         ...        ...      ...   ...           ...                ... ..
# 70           1          0       17   ...             2                  1  1
# 71           1          0       17   ...             2                  1  0
# 72           1          0       17   ...             2                  1  1
# 73           1          0       17   ...             2                  1  0
# 74           1          0       17   ...             2                  1  0
# 75           2          1        1   ...             1                  2  1
# 76           2          1        1   ...             1                  2  2
# 77           2          1        1   ...             1                  2  2
# 78           2          1        1   ...             1                  2  1
# 79           2          1        1   ...             1                  2  1
# 80           2          1        1   ...             1                  2  1
# 81           1          0       15   ...             2                  8  1
# 82           1          0       15   ...             2                  8  1
# 83           1          0       15   ...             2                  8  1
# 84           1          0       15   ...             2                  8  1
# 85           1          0       15   ...             2                  8  1
# 86           1          0       15   ...             2                  8  1
# 87           1          0       15   ...             2                  8  1
# 88           1          0       15   ...             2                  8  1
# 89           1          1       12   ...             4                 14  1
# 90           1          1       12   ...             4                 14  2
# 91           1          1       12   ...             4                 14  2
# 92           1          1       12   ...             4                 14  2
# 93           1          1       12   ...             4                 14  1
# 94           1          1       12   ...             4                 14  2
# 95           1          0       12   ...             4                 14  1
# 96           1          1        8   ...           NaN                NaN  0
# 97           1          1        8   ...           NaN                NaN  0
# 98           1          1        8   ...             1                  5  0
# 99           1          1        8   ...             1                  5  1
#
#     B  C  D  E  F  G  cost
# 0   0  2  2  1  2  2   633
# 1   0  2  2  1  2  1   630
# 2   0  2  2  1  2  1   630
# 3   0  2  2  1  2  1   630
# 4   0  2  2  1  2  1   630
# 5   0  2  2  1  2  1   638
# 6   0  2  2  1  2  1   638
# 7   0  2  2  1  2  1   638
# 8   0  2  2  1  2  1   634
# 9   1  3  3  1  0  2   755
# 10  1  3  3  1  0  2   755
# 11  1  3  3  1  0  2   755
# 12  0  3  2  0  0  2   730
# 13  0  3  2  0  0  2   731
# 14  0  3  2  0  0  2   731
# 15  0  2  3  0  0  3   618
# 16  0  2  3  0  0  1   616
# 17  0  1  1  0  0  1   607
# 18  0  1  1  0  0  1   607
# 19  0  1  1  0  0  1   607
# 20  0  2  2  0  0  1   605
# 21  0  2  2  0  0  1   605
# 22  0  1  2  0  0  1   602
# 23  1  3  2  1  2  3   629
# 24  1  3  2  1  2  3   620
# 25  1  3  2  1  1  3   627
# 26  1  3  2  1  1  3   626
# 27  1  3  3  0  2  2   604
# 28  1  1  1  0  2  2   585
# 29  1  1  1  0  2  2   603
# .. .. .. .. .. .. ..   ...
# 70  0  2  2  0  2  2   676
# 71  0  2  2  0  0  2   598
# 72  0  2  2  0  2  2   689
# 73  0  2  2  0  0  2   609
# 74  0  2  2  0  0  1   605
# 75  0  1  1  0  2  3   696
# 76  0  1  3  0  2  3   692
# 77  0  1  3  0  2  3   692
# 78  0  1  3  0  2  3   696
# 79  0  1  3  0  2  3   696
# 80  0  1  3  0  2  3   703
# 81  1  3  3  1  1  1   657
# 82  1  1  1  0  1  2   654
# 83  1  1  1  0  1  2   665
# 84  1  1  1  0  1  2   665
# 85  1  1  1  0  1  2   665
# 86  1  1  1  0  1  2   665
# 87  1  1  1  0  1  2   665
# 88  1  1  1  0  1  2   665
# 89  1  3  3  0  1  2   594
# 90  1  3  3  0  3  2   585
# 91  1  3  3  0  3  3   603
# 92  1  3  3  0  3  3   603
# 93  1  3  3  0  2  3   610
# 94  1  3  3  0  3  3   603
# 95  1  3  3  0  2  3   606
# 96  0  1  1  0  0  1   550
# 97  0  1  1  0  0  2   551
# 98  0  1  1  0  0  2   583
# 99  0  1  1  0  2  2   610
#
# [100 rows x 25 columns]

# %%
print df.columns
print df_test.columns
# Out:
# Index([u'customer_ID', u'shopping_pt', u'record_type', u'day', u'time', u'state', u'location', u'group_size', u'homeowner', u'car_age', u'car_value', u'risk_factor', u'age_oldest', u'age_youngest', u'married_couple', u'C_previous', u'duration_previous', u'A', u'B', u'C', u'D', u'E', u'F', u'G', u'cost'], dtype='object')
# Index([u'customer_ID', u'shopping_pt', u'record_type', u'day', u'time', u'state', u'location', u'group_size', u'homeowner', u'car_age', u'car_value', u'risk_factor', u'age_oldest', u'age_youngest', u'married_couple', u'C_previous', u'duration_previous', u'A', u'B', u'C', u'D', u'E', u'F', u'G', u'cost'], dtype='object')

# %%
for col in df.columns:
    
    temp =  "print "+"df." + col+".value_counts()"
    print temp
# Out:
# print df.customer_ID.value_counts()
# print df.shopping_pt.value_counts()
# print df.record_type.value_counts()
# print df.day.value_counts()
# print df.time.value_counts()
# print df.state.value_counts()
# print df.location.value_counts()
# print df.group_size.value_counts()
# print df.homeowner.value_counts()
# print df.car_age.value_counts()
# print df.car_value.value_counts()
# print df.risk_factor.value_counts()
# print df.age_oldest.value_counts()
# print df.age_youngest.value_counts()
# print df.married_couple.value_counts()
# print df.C_previous.value_counts()
# print df.duration_previous.value_counts()
# print df.A.value_counts()
# print df.B.value_counts()
# print df.C.value_counts()
# print df.D.value_counts()
# print df.E.value_counts()
# print df.F.value_counts()
# print df.G.value_counts()
# print df.cost.value_counts()

# %%
print df.customer_ID.value_counts()
print df.shopping_pt.value_counts()
print df.record_type.value_counts()
print df.day.value_counts()
print df.time.value_counts()
print df.state.value_counts()
print df.location.value_counts()
print df.group_size.value_counts()
print df.homeowner.value_counts()
print df.car_age.value_counts()
print df.car_value.value_counts()
print df.risk_factor.value_counts()
print df.age_oldest.value_counts()
print df.age_youngest.value_counts()
print df.married_couple.value_counts()
print df.C_previous.value_counts()
print df.duration_previous.value_counts()
print df.A.value_counts()
print df.B.value_counts()
print df.C.value_counts()
print df.D.value_counts()
print df.E.value_counts()
print df.F.value_counts()
print df.G.value_counts()
print df.cost.value_counts()
# Out:
# 10046542    13
# 10108594    13
# 10003496    13
# 10110519    13
# 10075547    13
# 10129147    13
# 10018597    13
# 10110688    13
# 10050088    13
# 10018030    13
# 10093351    13
# 10027238    13
# 10108739    13
# 10013536    13
# 10068933    13
# ...
# 10004474    3
# 10110663    3
# 10137628    3
# 10128523    3
# 10047056    3
# 10010535    3
# 10140528    3
# 10137306    3
# 10126199    3
# 10040060    3
# 10144638    3
# 10038774    3
# 10072812    3
# 10084896    3
# 10032033    3
# Length: 97009, dtype: int64
# 3     97009
# 2     97009
# 1     97009
# 4     91441
# 5     83440
# 6     72171
# 7     56548
# 8     37958
# 9     20710
# 10     8725
# 11     2654
# 12      525
# 13       50
# dtype: int64
# 0    568240
# 1     97009
# dtype: int64
# 0    140539
# 1    136921
# 2    133453
# 4    123639
# 3    121342
# 5      8378
# 6       977
# dtype: int64
# 14:35    1553
# 14:59    1489
# 14:57    1471
# 15:22    1454
# 15:20    1453
# 15:09    1452
# 14:40    1441
# 14:16    1440
# 14:39    1435
# 15:13    1432
# 14:38    1430
# 13:42    1428
# 15:03    1425
# 14:25    1423
# 14:56    1420
# ...
# 01:34    1
# 01:30    1
# 01:59    1
# 02:40    1
# 02:04    1
# 02:03    1
# 04:46    1
# 04:00    1
# 04:02    1
# 05:12    1
# 05:11    1
# 05:10    1
# 06:27    1
# 04:47    1
# 05:23    1
# Length: 1204, dtype: int64
# FL    106287
# NY     91627
# PA     60677
# OH     44537
# MD     28443
# IN     25295
# WA     25188
# CO     24409
# AL     23560
# CT     19353
# TN     18099
# KY     16100
# NV     15459
# MO     15243
# OR     15068
# UT     14820
# OK     13779
# MS     10722
# AR     10460
# WI     10103
# GA      8802
# NH      7988
# ME      6800
# NM      6790
# ID      6110
# RI      5887
# KS      5585
# WV      5053
# IA      4545
# DE      4101
# DC      3748
# MT      3332
# NE      3121
# ND      2487
# WY      1163
# SD       508
# dtype: int64
# 10083    1094
# 10213     977
# 10348     974
# 11196     869
# 11517     864
# 10030     798
# 12091     731
# 10723     703
# 10793     701
# 10245     682
# 10750     677
# 11179     667
# 10016     658
# 11580     626
# 10082     622
# ...
# 15319    2
# 14363    2
# 14404    2
# 14412    2
# 13175    2
# 16166    1
# 14702    1
# 16026    1
# 15033    1
# 16299    1
# 15226    1
# 16206    1
# 15697    1
# 15220    1
# 13691    1
# Length: 6248, dtype: int64
# 1    519305
# 2    136393
# 3      8856
# 4       695
# dtype: int64
# 1    356726
# 0    308523
# dtype: int64
# 1     71650
# 2     50389
# 7     46752
# 8     44453
# 6     44363
# 9     44218
# 4     40991
# 3     40391
# 10    39301
# 11    36173
# 5     32806
# 12    32113
# 13    26628
# 14    25026
# 15    19041
# ...
# 62    15
# 61    14
# 51    14
# 53    13
# 52    11
# 59    10
# 58     8
# 57     7
# 64     6
# 75     6
# 55     6
# 65     5
# 60     4
# 85     4
# 54     1
# Length: 67, dtype: int64
# e    219251
# f    177204
# d    113174
# g     98152
# h     28976
# c     20820
# i      3603
# b      1402
# a      1136
# dtype: int64
# 3    117571
# 4    110754
# 1     99476
# 2     97030
# dtype: int64
# 75    45211
# 24    21627
# 23    21489
# 25    21278
# 22    19692
# 26    18679
# 27    16046
# 28    15180
# 21    14255
# 29    13179
# 30    12874
# 31    11982
# 32    11658
# 33    11461
# 43    11321
# 55    11206
# 42    11129
# 52    11029
# 34    10980
# 53    10839
# 46    10748
# 56    10680
# 35    10665
# 48    10632
# 49    10595
# 54    10558
# 58    10462
# 51    10447
# 50    10250
# 44    10205
# 45    10190
# 20    10180
# 59    10169
# 41    10135
# 36     9948
# 57     9873
# 47     9860
# 37     9831
# 66     9707
# 38     9700
# 63     9663
# 65     9651
# 60     9617
# 40     9573
# 61     9491
# 39     9480
# 62     9348
# 64     9315
# 70     8278
# 69     7604
# 67     7538
# 68     6957
# 71     6825
# 19     6592
# 72     6194
# 73     5861
# 74     5646
# 18     1666
# Length: 58, dtype: int64
# 75    34262
# 23    24208
# 24    23635
# 25    23509
# 22    22290
# 26    20510
# 27    17718
# 21    17311
# 28    16832
# 29    14437
# 30    13807
# 20    13480
# 31    12961
# 32    12520
# 33    12118
# 34    11466
# 35    11080
# 55    10298
# 42    10200
# 19    10182
# 43    10117
# 52    10026
# 36     9904
# 48     9829
# 37     9825
# 53     9803
# 46     9743
# 51     9713
# 49     9674
# 58     9673
# 56     9581
# 38     9568
# 41     9533
# 54     9511
# 50     9510
# 45     9380
# 40     9365
# 44     9291
# 65     9142
# 57     9120
# 39     9085
# 47     8931
# 59     8901
# 60     8859
# 66     8800
# 62     8707
# 61     8697
# 63     8606
# 64     8591
# 70     7295
# 69     6987
# 68     6397
# 67     6187
# 71     6102
# 72     5234
# 73     5152
# 18     5093
# 74     5048
# 16     4478
# 17     2967
# Length: 60, dtype: int64
# 0    525692
# 1    139557
# dtype: int64
# 3    271160
# 1    172007
# 2    109184
# 4     94187
# dtype: int64
# 1     81570
# 15    79849
# 2     79595
# 3     70800
# 4     57485
# 5     49372
# 6     45379
# 7     37768
# 8     30752
# 9     26244
# 0     24926
# 10    18094
# 11    12718
# 12    11284
# 13    10963
# 14     9739
# dtype: int64
# 1    426067
# 0    143691
# 2     95491
# dtype: int64
# 0    363069
# 1    302180
# dtype: int64
# 3    271607
# 1    202945
# 2    133468
# 4     57229
# dtype: int64
# 3    408839
# 2    149793
# 1    106617
# dtype: int64
# 0    369085
# 1    296164
# dtype: int64
# 2    255806
# 0    216395
# 1    158613
# 3     34435
# dtype: int64
# 2    265237
# 3    191163
# 1    141946
# 4     66903
# dtype: int64
# 633    6024
# 637    5985
# 640    5935
# 626    5934
# 638    5916
# 639    5912
# 629    5896
# 642    5894
# 635    5875
# 623    5854
# 628    5823
# 621    5780
# 631    5777
# 624    5766
# 632    5766
# ...
# 418    1
# 416    1
# 922    1
# 408    1
# 917    1
# 400    1
# 911    1
# 385    1
# 888    1
# 376    1
# 375    1
# 881    1
# 362    1
# 873    1
# 863    1
# Length: 531, dtype: int64

# %%
df.corr()
# Out:
#                    customer_ID  shopping_pt  record_type       day  location  \
# customer_ID           1.000000     0.000506     0.000016  0.001761  0.048883
# shopping_pt           0.000506     1.000000     0.455160  0.012806  0.000283
# record_type           0.000016     0.455160     1.000000  0.032195  0.000350
# day                   0.001761     0.012806     0.032195  1.000000 -0.011176
# location              0.048883     0.000283     0.000350 -0.011176  1.000000
# group_size            0.005351     0.012702     0.000747 -0.000323 -0.004288
# homeowner             0.000411    -0.021256     0.007669 -0.006198  0.001556
# car_age              -0.002184    -0.020861     0.002984  0.003359  0.007609
# risk_factor           0.003107    -0.003281    -0.000739  0.010340  0.008540
# age_oldest            0.002723    -0.004015     0.004492 -0.020495 -0.000610
# age_youngest          0.000524    -0.010768     0.002484 -0.023220  0.001444
# married_couple        0.000753     0.012724     0.001938 -0.001084 -0.003156
# C_previous           -0.004146    -0.002259     0.003744 -0.010852  0.014698
# duration_previous    -0.000737    -0.004659     0.007947 -0.006710  0.016669
# A                    -0.002306     0.052803     0.012162 -0.001005 -0.003494
# B                    -0.003188     0.046609     0.018135  0.001314 -0.007643
# C                    -0.000207     0.000680     0.006821 -0.012000  0.009657
# D                    -0.000540     0.067658     0.033951 -0.006805 -0.041001
# E                    -0.003091     0.042514     0.014477 -0.004314 -0.012558
# F                    -0.002457     0.041894     0.001792 -0.005613 -0.031134
# G                     0.001958    -0.023635     0.001428 -0.009100  0.030187
# cost                 -0.002250     0.043419    -0.011826  0.010793  0.002413
#
#                    group_size  homeowner   car_age  risk_factor  age_oldest  \
# customer_ID          0.005351   0.000411 -0.002184     0.003107    0.002723
# shopping_pt          0.012702  -0.021256 -0.020861    -0.003281   -0.004015
# record_type          0.000747   0.007669  0.002984    -0.000739    0.004492
# day                 -0.000323  -0.006198  0.003359     0.010340   -0.020495
# location            -0.004288   0.001556  0.007609     0.008540   -0.000610
# group_size           1.000000   0.203836 -0.026222    -0.058418    0.217449
# homeowner            0.203836   1.000000 -0.053620    -0.179573    0.418845
# car_age             -0.026222  -0.053620  1.000000     0.084049    0.009408
# risk_factor         -0.058418  -0.179573  0.084049     1.000000   -0.302998
# age_oldest           0.217449   0.418845  0.009408    -0.302998    1.000000
# age_youngest        -0.024050   0.365679  0.005757    -0.296139    0.913165
# married_couple       0.772830   0.199614 -0.036876    -0.082848    0.228537
# C_previous           0.079346   0.116108 -0.139923    -0.128921    0.078344
# duration_previous    0.074635   0.193181 -0.037537    -0.176468    0.288918
# A                    0.017806   0.048471 -0.436740    -0.060140    0.003914
# B                    0.027647   0.033747 -0.089334    -0.011725    0.025027
# C                    0.088286   0.183508 -0.167185    -0.162796    0.156608
# D                    0.045749   0.108537 -0.137913    -0.135076    0.083714
# E                    0.022505   0.080747 -0.277963    -0.104422    0.100000
# F                    0.010347   0.031474 -0.248727     0.064578   -0.012279
# G                    0.047601   0.094525 -0.084395    -0.192723    0.141886
# cost                -0.024009  -0.213846 -0.281002     0.127908   -0.210225
#
#                       ...      C_previous  duration_previous         A  \
# customer_ID           ...       -0.004146          -0.000737 -0.002306
# shopping_pt           ...       -0.002259          -0.004659  0.052803
# record_type           ...        0.003744           0.007947  0.012162
# day                   ...       -0.010852          -0.006710 -0.001005
# location              ...        0.014698           0.016669 -0.003494
# group_size            ...        0.079346           0.074635  0.017806
# homeowner             ...        0.116108           0.193181  0.048471
# car_age               ...       -0.139923          -0.037537 -0.436740
# risk_factor           ...       -0.128921          -0.176468 -0.060140
# age_oldest            ...        0.078344           0.288918  0.003914
# age_youngest          ...        0.071151           0.259316  0.005199
# married_couple        ...        0.067941           0.061029  0.023021
# C_previous            ...        1.000000           0.145661  0.123160
# duration_previous     ...        0.145661           1.000000  0.030471
# A                     ...        0.123160           0.030471  1.000000
# B                     ...        0.033384           0.006563  0.158040
# C                     ...        0.654217           0.155519  0.190519
# D                     ...        0.411490           0.103054  0.189351
# E                     ...        0.111482           0.075439  0.324618
# F                     ...       -0.033508          -0.015969  0.531186
# G                     ...        0.099414           0.153097  0.045335
# cost                  ...       -0.084393          -0.165836  0.325922
#
#                           B         C         D         E         F         G  \
# customer_ID       -0.003188 -0.000207 -0.000540 -0.003091 -0.002457  0.001958
# shopping_pt        0.046609  0.000680  0.067658  0.042514  0.041894 -0.023635
# record_type        0.018135  0.006821  0.033951  0.014477  0.001792  0.001428
# day                0.001314 -0.012000 -0.006805 -0.004314 -0.005613 -0.009100
# location          -0.007643  0.009657 -0.041001 -0.012558 -0.031134  0.030187
# group_size         0.027647  0.088286  0.045749  0.022505  0.010347  0.047601
# homeowner          0.033747  0.183508  0.108537  0.080747  0.031474  0.094525
# car_age           -0.089334 -0.167185 -0.137913 -0.277963 -0.248727 -0.084395
# risk_factor       -0.011725 -0.162796 -0.135076 -0.104422  0.064578 -0.192723
# age_oldest         0.025027  0.156608  0.083714  0.100000 -0.012279  0.141886
# age_youngest       0.017528  0.150086  0.082179  0.098819 -0.007272  0.133767
# married_couple     0.020741  0.092422  0.048813  0.033230 -0.000733  0.045304
# C_previous         0.033384  0.654217  0.411490  0.111482 -0.033508  0.099414
# duration_previous  0.006563  0.155519  0.103054  0.075439 -0.015969  0.153097
# A                  0.158040  0.190519  0.189351  0.324618  0.531186  0.045335
# B                  1.000000  0.093611  0.122656  0.461271  0.128231  0.024826
# C                  0.093611  1.000000  0.639530  0.196055 -0.012188  0.107925
# D                  0.122656  0.639530  1.000000  0.192280  0.030317  0.103398
# E                  0.461271  0.196055  0.192280  1.000000  0.159579  0.102273
# F                  0.128231 -0.012188  0.030317  0.159579  1.000000  0.071318
# G                  0.024826  0.107925  0.103398  0.102273  0.071318  1.000000
# cost               0.118573 -0.033931  0.002963  0.259183  0.141707 -0.011274
#
#                        cost
# customer_ID       -0.002250
# shopping_pt        0.043419
# record_type       -0.011826
# day                0.010793
# location           0.002413
# group_size        -0.024009
# homeowner         -0.213846
# car_age           -0.281002
# risk_factor        0.127908
# age_oldest        -0.210225
# age_youngest      -0.238497
# married_couple    -0.075193
# C_previous        -0.084393
# duration_previous -0.165836
# A                  0.325922
# B                  0.118573
# C                 -0.033931
# D                  0.002963
# E                  0.259183
# F                  0.141707
# G                 -0.011274
# cost               1.000000
#
# [22 rows x 22 columns]

# %%
df['A'].diff().hist()

# %%
print df.record_type.value_counts()
print df.shopping_pt.value_counts()
# Out:
# 0    568240
# 1     97009
# dtype: int64
# 3     97009
# 2     97009
# 1     97009
# 4     91441
# 5     83440
# 6     72171
# 7     56548
# 8     37958
# 9     20710
# 10     8725
# 11     2654
# 12      525
# 13       50
# dtype: int64

# %%
print len(df)
df = df.dropna()
# Out:
# 665249

# %%
def getLabels():
    y = df.record_type.values
    return y

# %%
y = getLabels()
print y
print len(y)
# Out:
# [0 0 0 ..., 0 0 1]
# 417447

# %%
df.columns
# Out:
# Index([u'customer_ID', u'shopping_pt', u'record_type', u'day', u'time', u'state', u'location', u'group_size', u'homeowner', u'car_age', u'car_value', u'risk_factor', u'age_oldest', u'age_youngest', u'married_couple', u'C_previous', u'duration_previous', u'A', u'B', u'C', u'D', u'E', u'F', u'G', u'cost'], dtype='object')

# %%
df.dtypes
# Out:
# customer_ID            int64
# shopping_pt            int64
# record_type            int64
# day                    int64
# time                  object
# state                 object
# location               int64
# group_size             int64
# homeowner              int64
# car_age                int64
# car_value             object
# risk_factor          float64
# age_oldest             int64
# age_youngest           int64
# married_couple         int64
# C_previous           float64
# duration_previous    float64
# A                      int64
# B                      int64
# C                      int64
# D                      int64
# E                      int64
# F                      int64
# G                      int64
# cost                   int64
# dtype: object

# %%
#df_X = df.drop(['record_type','day','time','state','car_value'], axis=1)
df.head()
# Out:
#    customer_ID  shopping_pt  record_type  day   time state  location  \
# 0     10000000            1            0    0  08:35    IN     10001
# 1     10000000            2            0    0  08:38    IN     10001
# 2     10000000            3            0    0  08:38    IN     10001
# 3     10000000            4            0    0  08:39    IN     10001
# 4     10000000            5            0    0  11:55    IN     10001
#
#    group_size  homeowner  car_age   ...    C_previous  duration_previous  A  \
# 0           2          0        2   ...             1                  2  1
# 1           2          0        2   ...             1                  2  1
# 2           2          0        2   ...             1                  2  1
# 3           2          0        2   ...             1                  2  1
# 4           2          0        2   ...             1                  2  1
#
#    B  C  D  E  F  G  cost
# 0  0  2  2  1  2  2   633
# 1  0  2  2  1  2  1   630
# 2  0  2  2  1  2  1   630
# 3  0  2  2  1  2  1   630
# 4  0  2  2  1  2  1   630
#
# [5 rows x 25 columns]

# %%
df_X = df
df_X = df_X.drop(['record_type','day','time','state','car_value'], axis=1)
df_X.head()
# Out:
#    customer_ID  shopping_pt  location  group_size  homeowner  car_age  \
# 0     10000000            1     10001           2          0        2
# 1     10000000            2     10001           2          0        2
# 2     10000000            3     10001           2          0        2
# 3     10000000            4     10001           2          0        2
# 4     10000000            5     10001           2          0        2
#
#    risk_factor  age_oldest  age_youngest  married_couple  C_previous  \
# 0            3          46            42               1           1
# 1            3          46            42               1           1
# 2            3          46            42               1           1
# 3            3          46            42               1           1
# 4            3          46            42               1           1
#
#    duration_previous  A  B  C  D  E  F  G  cost
# 0                  2  1  0  2  2  1  2  2   633
# 1                  2  1  0  2  2  1  2  1   630
# 2                  2  1  0  2  2  1  2  1   630
# 3                  2  1  0  2  2  1  2  1   630
# 4                  2  1  0  2  2  1  2  1   630

# %%
df_X.dtypes
df_X.fillna(df_X.mean())
df_X = df_X.dropna()

# %%
# df_features = pd.DataFrame(np.random.randn(0,1),columns=['fbscore','tscore'])
# df_features.head()
df_X.shape
# Out:
# (417447, 20)

# %%
X = np.array(df_X)

# %%
from sklearn.metrics import roc_curve, auc

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
clf  = LogisticRegression(C=1, penalty='l2', tol=0.01)
scores = cross_validation.cross_val_score(clf, X, y, cv=5)
print "%s -- %s" % (clf.__class__, np.mean(scores))

""" fit and predict model """
clf.fit(X_train, y_train)

probas_ = clf.predict_proba(X_test)


fpr, tpr,thresholds = roc_curve(y_test, probas_[:, 1]) # recall my labels are 4,5 and 6
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)
# Out:
# <class 'sklearn.linear_model.logistic.LogisticRegression'> -- 0.850867295723
# Area under the ROC curve : 0.499304

# %%
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
clf = ()
clf = RandomForestClassifier(verbose=10, n_estimators=10, n_jobs=-1, compute_importances=True,max_features=5, oob_score=True)
scores = cross_validation.cross_val_score(clf, X, y, cv=5)
print "%s -- %s" % (clf.__class__, np.mean(scores))

""" fit and predict model """
clf.fit(X_train, y_train)

""" fit and predict model """
clf.fit(X_train, y_train)

probas_ = clf.predict_proba(X_test)


fpr, tpr,thresholds = roc_curve(y_test, probas_[:, 1]) # recall my labels are 4,5 and 6
roc_auc = auc(fpr, tpr)
print("Area under the ROC curve : %f" % roc_auc)
# Out:
# /Users/Prasad/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:783: DeprecationWarning: Setting compute_importances is no longer required as version 0.14. Variable importances are now computed on the fly when accessing the feature_importances_ attribute. This parameter will be removed in 0.16.
#   DeprecationWarning)
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   31.8s remaining:   31.8s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   34.0s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# /Users/Prasad/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.py:397: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    1.0s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   31.2s remaining:   31.2s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   31.2s finished
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.7s remaining:    0.7s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    1.0s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   32.5s remaining:   32.5s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   32.5s finished
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    1.0s finished
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   31.3s remaining:   31.3s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   33.8s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    1.0s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   33.3s remaining:   33.3s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   33.3s finished
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.8s remaining:    0.8s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    1.0s finished
# <class 'sklearn.ensemble.forest.RandomForestClassifier'> -- 0.854628253668
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   40.4s remaining:   40.4s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   40.8s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:   40.1s remaining:   40.1s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:   41.8s finished
# building tree 1 of 5
# building tree 1 of 5
# building tree 2 of 5building tree 2 of 5
#
# building tree 3 of 5building tree 3 of 5
#
# building tree 4 of 5building tree 4 of 5
#
# building tree 5 of 5building tree 5 of 5
# [Parallel(n_jobs=2)]: Done   1 out of   2 | elapsed:    0.6s remaining:    0.6s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    0.9s finished
# Area under the ROC curve : 0.788635

# %%
plt.figure()
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
plt.savefig('ROC-plot-RF.png')

# %%
clf.get_params
# Out:
# <bound method RandomForestClassifier.get_params of RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features=5,
#             min_density=None, min_samples_leaf=1, min_samples_split=2,
#             n_estimators=10, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=10)>

# %%
clf.feature_importances_
# Out:
# array([ 0.1044872 ,  0.26285553,  0.10309011,  0.00989955,  0.01002562,
#         0.06230579,  0.0271521 ,  0.06429202,  0.06511593,  0.00841076,
#         0.02149941,  0.05392792,  0.01165137,  0.0118037 ,  0.0184484 ,
#         0.0113915 ,  0.00972413,  0.01815621,  0.02221255,  0.10355018])

# %%
features = df_X.columns
imps = clf.feature_importances_

for i in range(len(imps)):
    print features[i], imps[i]


impdf = pd.DataFrame([features,imps]).T
impdf = impdf.set_index(0)
impdf.sort(1).plot(kind='bar',)
impdf.head()
# print features
# np.argsort(clf.feature_importances_)
# Out:
# customer_ID 0.104487195374
# shopping_pt 0.262855533989
# location 0.103090108598
# group_size 0.00989955155526
# homeowner 0.0100256164651
# car_age 0.0623057940875
# risk_factor 0.0271521045696
# age_oldest 0.0642920203201
# age_youngest 0.0651159323184
# married_couple 0.00841076473854
# C_previous 0.0214994117021
# duration_previous 0.053927924508
# A 0.0116513737987
# B 0.0118036973705
# C 0.0184484043523
# D 0.0113914986859
# E 0.00972413301961
# F 0.0181562093442
# G 0.0222125461562
# cost 0.103550179048
#                        1
# 0
# customer_ID    0.1044872
# shopping_pt    0.2628555
# location       0.1030901
# group_size   0.009899552
# homeowner     0.01002562

# %%
features[np.argsort(clf.feature_importances_)]
# Out:
# Index([u'married_couple', u'E', u'group_size', u'homeowner', u'D', u'A', u'B', u'F', u'C', u'C_previous', u'G', u'risk_factor', u'duration_previous', u'car_age', u'age_oldest', u'age_youngest', u'location', u'cost', u'customer_ID', u'shopping_pt'], dtype='object')

# %%
# from sklearn.pipeline import Pipeline
# from sklearn.grid_search import GridSearchCV
# from sklearn import grid_search
# from sklearn import metrics
# import time
# import pprint



# parameters = {'penalty':['l1', 'l2'], 'class_weight':['auto'],'C':[0.1,1,10],'tol':[0.001,0.01,0.1]}
# lr = LogisticRegression()
# #grid_search = GridSearchCV(lr, parameters, n_jobs=-1, verbose=1, scoring="roc_auc", cv=5)
# clf = grid_search.GridSearchCV(lr, parameters)

# print("Performing grid search...")
# print("parameters:")
# t0 = time.time()
# clf.fit(X_train, y_train)
# print("done in %0.3fs" % (time() - t0))
# print()

# print("Best score: %0.3f" % clf.best_score_)
# print("Best parameters set:")
# best_parameters = clf.best_estimator_.get_params()
# for param_name in sorted(parameters.keys()):
#     print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %%
# parameters = {'verbose':['10'], 'n_estimators':[4,6,10],'n_jobs':[-1]}
# rf = RandomForestClassifier()
# #grid_search = GridSearchCV(lr, parameters, n_jobs=-1, verbose=1, scoring="roc_auc", cv=5)
# #clf = RandomForestClassifier(verbose=10, n_estimators=10, n_jobs=-1, compute_importances=True,max_features=5, oob_score=True)

# clf = grid_search.GridSearchCV(lr, parameters)

# print("Performing grid search...")
# print("parameters:")
# t0 = time.time()
# clf.fit(X_train, y_train)
# print("done in %0.3fs" % (time() - t0))
# print()

# print("Best score: %0.3f" % clf.best_score_)
# print("Best parameters set:")
# best_parameters = clf.best_estimator_.get_params()
# for param_name in sorted(parameters.keys()):
#     print("\t%s: %r" % (param_name, best_parameters[param_name]))

# %%
print df.A.value_counts()
print df.B.value_counts()
print df.C.value_counts()
print df.D.value_counts()
print df.E.value_counts()
print df.F.value_counts()
print df.G.value_counts()
# Out:
# 1    281462
# 0     77400
# 2     58585
# dtype: int64
# 0    222711
# 1    194736
# dtype: int64
# 3    191677
# 1     98299
# 2     79860
# 4     47611
# dtype: int64
# 3    284583
# 2     86336
# 1     46528
# dtype: int64
# 0    212804
# 1    204643
# dtype: int64
# 2    153539
# 0    145593
# 1    101085
# 3     17230
# dtype: int64
# 2    156088
# 3    142053
# 1     70653
# 4     48653
# dtype: int64

# %%
from graphlab import recommender, SFrame

# m = recommender.create(data, user_column='customer_ID', item_column='A')
# recs = m.recommend(users=['u1', 'u3', 'u15'])
# print recs

df_s = df[df.record_type ==1]
df.shape
df.record_type.value_counts()
sf = SFrame(data=df_s)
sf
df_s.head()
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-3268 - Server binary: /Users/Prasad/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1405538381.log
# [INFO] GraphLab Server Version: 0.3.0
#     customer_ID  shopping_pt  record_type  day   time state  location  \
# 8      10000000            9            1    0  12:07    IN     10001
# 14     10000005            6            1    3  09:09    NY     10006
# 26     10000013            4            1    4  09:31    WV     10014
# 32     10000014            6            1    1  17:50    MO     10015
# 57     10000023            7            1    1  14:32    PA     10025
#
#     group_size  homeowner  car_age   ...    C_previous  duration_previous  A  \
# 8            2          0        2   ...             1                  2  1
# 14           1          0       10   ...             3                 13  0
# 26           2          1        3   ...             3                  3  1
# 32           1          0        5   ...             1                  2  1
# 57           1          1        2   ...             1                 13  1
#
#     B  C  D  E  F  G  cost
# 8   0  2  2  1  2  1   634
# 14  0  3  2  0  0  2   731
# 26  1  3  2  1  1  3   626
# 32  1  1  1  0  2  2   614
# 57  1  1  3  1  1  2   607
#
# [5 rows x 25 columns]

# %%
for i in ['A','B','C','D','E','F','G']:
    m = recommender.create(sf, user_column='customer_ID', item_column=i)
    recs = m.recommend(users=[10000026])
    print recs
# Out:
#    customer_ID  A  score  rank
# 0     10000026  0      0     1
# [2 rows x 4 columns]
#
#    customer_ID  B  score  rank
# [1 rows x 4 columns]
#    customer_ID  C  score  rank
# 0     10000026  2      0     1
# 1     10000026  1      0     2
# [3 rows x 4 columns]
#    customer_ID  D  score  rank
# 0     10000026  2      0     1
# [2 rows x 4 columns]
#    customer_ID  E  score  rank
# [1 rows x 4 columns]
#    customer_ID  F  score  rank
# 0     10000026  0      0     1
# 1     10000026  1      0     2
# [3 rows x 4 columns]
#    customer_ID  G  score  rank
# 0     10000026  1      0     1
# 1     10000026  2      0     2
# [3 rows x 4 columns]

# %%
df[df.customer_ID==10000026]
# Out:
#     customer_ID  shopping_pt  record_type  day   time state  location  \
# 65     10000026            1            0    1  09:09    OH     10028
# 66     10000026            2            0    1  09:09    OH     10028
# 67     10000026            3            0    1  09:10    OH     10028
# 68     10000026            4            1    3  15:24    OH     10028
#
#     group_size  homeowner  car_age   ...    C_previous  duration_previous  A  \
# 65           2          1        5   ...             3                  1  1
# 66           2          1        5   ...             3                  1  1
# 67           2          1        5   ...             3                  1  1
# 68           2          1        5   ...             3                  1  1
#
#     B  C  D  E  F  G  cost
# 65  0  3  3  0  2  3   556
# 66  0  3  3  0  2  3   556
# 67  1  3  3  1  2  3   572
# 68  1  3  3  1  2  3   578
#
# [4 rows x 25 columns]

# %%
print df_X.shape
print df_X.shape

# %%
df.shape
# Out:
# (665249, 25)

# %%
df['costperperson'] = 1.0 * df.cost/df.group_size

# %%
df.shape
# Out:
# (665249, 26)

# %%
df.costperperson.value_counts()
# Out:
# 633    4784
# 640    4738
# 642    4733
# 638    4728
# 637    4708
# 623    4666
# 629    4663
# 628    4620
# 639    4610
# 648    4603
# 635    4597
# 626    4586
# 650    4584
# 631    4570
# 624    4562
# ...
# 196.750000    1
# 476.000000    1
# 470.000000    1
# 467.000000    1
# 457.000000    1
# 454.000000    1
# 438.000000    1
# 428.000000    1
# 427.000000    1
# 423.000000    1
# 455.500000    1
# 410.000000    1
# 263.666667    1
# 409.500000    1
# 172.666667    1
# Length: 1217, dtype: int64

# %%
x = df.columns.tolist()
print x
# Out:
# ['customer_ID', 'shopping_pt', 'record_type', 'day', 'time', 'state', 'location', 'group_size', 'homeowner', 'car_age', 'car_value', 'risk_factor', 'age_oldest', 'age_youngest', 'married_couple', 'C_previous', 'duration_previous', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'cost', 'costperperson']

# %%
Z1 = df[['customer_ID','shopping_pt']]
Z2 = df[['costperperson']]

# %%
Z3 = Z1 + Z2

# %%
Z3.head()
# Out:
#    costperperson  customer_ID  shopping_pt
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# 2            NaN          NaN          NaN
# 3            NaN          NaN          NaN
# 4            NaN          NaN          NaN
